# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaNtm/Energy-price-predictions/blob/main/Day_Ahead_Nominations_of_Forward_Net_Delivery_and_Offtake_Positions(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instruction page: https://www.enexgroup.gr/documents/20126/214481/YYYYMMDD_EL-DAM_POSNOMS_EN_v%23%23%28Documentation%29.pdf/732af1ca-2d39-528a-a3e3-ea695f1d98f4?t=1598481978711

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import requests
from datetime import datetime, timedelta

# %%
import zipfile

# %% [markdown]
# #Loop the automated URL and import the excel files to the dataframe

# %%
base_url = "https://www.enexgroup.gr/documents/20126/214481/"

# %%
start_date = datetime(2023, 1, 3)
end_date = datetime(2023, 7, 3) #past from that we have no information on the page
date_format = "%Y%m%d"

# %%
current_date = start_date

# %%
# Initialize an empty DataFrame
df = pd.DataFrame()

# %%
while current_date <= end_date:
    # Check if the current day is not a Saturday (weekday() returns 5) and not a Sunday (weekday() returns 6)
    if current_date.weekday() not in [5, 6]:
        date_str = current_date.strftime(date_format)
        url = f"{base_url}{date_str}_EL-DAM_POSNOMs_EN_v01.xlsx"

        try:
            # Read the XLSX file into a pandas DataFrame
            df1 = pd.read_excel(url)
            df = pd.concat([df, df1])
        except Exception as e:
            print(f"Error reading URL: {url}")
            print(f"Error message: {e}")

    # Increment to the next date
    current_date += timedelta(days=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
df.head()
# Out:
#   TARGET SIDE_DESCR      DDAY ASSET_DESCR CLASSIFICATION         DELIVERY_MTU  \
# 0    DAM       Sell  20230103       AL-GR         Import  2023-01-03 00:00:00
# 1    DAM       Sell  20230103       AL-GR         Import  2023-01-03 01:00:00
# 2    DAM       Sell  20230103       AL-GR         Import  2023-01-03 02:00:00
# 3    DAM       Sell  20230103       AL-GR         Import  2023-01-03 03:00:00
# 4    DAM       Sell  20230103       AL-GR         Import  2023-01-03 04:00:00
#
#    DELIVERY_DURATION  SORT  TOTAL_ORDERS             PUB_TIME  VER
# 0                 60     1         152.0  2023-01-02 10:30:14    1
# 1                 60     2         152.0  2023-01-02 10:30:14    1
# 2                 60     3         152.0  2023-01-02 10:30:14    1
# 3                 60     4         152.0  2023-01-02 10:30:14    1
# 4                 60     5         152.0  2023-01-02 10:30:14    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18878 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TARGET             18878 non-null  object
#  1   SIDE_DESCR         18878 non-null  object
#  2   DDAY               18878 non-null  int64
#  3   ASSET_DESCR        18878 non-null  object
#  4   CLASSIFICATION     18878 non-null  object
#  5   DELIVERY_MTU       18878 non-null  object
#  6   DELIVERY_DURATION  18878 non-null  int64
#  7   SORT               18878 non-null  int64
#  8   TOTAL_ORDERS       18878 non-null  float64
#  9   PUB_TIME           18878 non-null  object
#  10  VER                18878 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.7+ MB

# %% [markdown]
# #Save to Google Drive

# %%
path = '/content/drive/My Drive/EL-DAM_POSNOMs_HENEX.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df.to_csv(f)
